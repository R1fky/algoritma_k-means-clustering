# %%
# c1 = (41,19)
# c2 = (47,100)
# Output yang harus kamu hasilkan:
# Jarak tiap titik ke C1 & C2
# Tentukan cluster tiap titik
# Hitung centroid baru

# %%
import pandas as pd

#membuat data frame
data = [(41,19), (47,100), (33,57), (29,19)]
columns = ['age', 'income']
datas = pd.DataFrame(data, columns=columns)

# %%
datas
# Out:
#    age  income
# 0   41      19
# 1   47     100
# 2   33      57
# 3   29      19

# %%
# nilai centroid 
centroid1 = datas.iloc[0]
centroid2 = datas.iloc[1]
centroid1
# Out:
# age       41
# income    19
# Name: 0, dtype: int64

# %%
centroid2
# Out:
# age        47
# income    100
# Name: 1, dtype: int64

# %%
# menghitung c1
# Out:
# age
# income
